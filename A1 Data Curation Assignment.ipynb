# %% [markdown]
# # Header goes here

# %%
import requests
import json

# %% [markdown]
# ### Endpoints and Wikimedia header

# %%
pagecount_endpoint = 'https://wikimedia.org/api/rest_v1/metrics/legacy/pagecounts/aggregate/{project}/{access-site}/{granularity}/{start}/{end}'

pageview_endpoint = 'https://wikimedia.org/api/rest_v1/metrics/pageviews/aggregate/{project}/{access}/{agent}/{granularity}/{start}/{end}'
headers = {
    'User-Agent': 'https://github.com/savageGrant',
    'From':'gtsavage@uw.edu'
}

# %% [markdown]
# ### API Parameters

# %%
# Legacy pagecount API params
legacy_pagecount = """{{"project" : "en.wikipedia.org",
                 "access-site" : "{placeholder}",
                 "granularity" : "monthly",
                 "start" : "2008010100",
                 "end" : "2016080100"
                    }}"""

legacy_pagecount_access_types = ['desktop-site', 'mobile-site']

# Pageview API params
pageview = """{{"project" : "en.wikipedia.org",
                 "access" : "{placeholder}",
                 "agent" : "user",
                 "granularity" : "monthly",
                 "start" : "2015070100",
                 "end" : "2021090100"
                    }}"""


pageview_access_types = ['desktop', 'mobile-web', 'mobile-app']

# %%
import os

os.path.abspath(os.curdir)
# Out:
# 'C:\\Users\\Grant\\OneDrive - UW\\Data 512\\Code\\data-512-a1'

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  'A1 Data Curation Assignment.ipynb',
#  'LICENSE',
#  'raw',
#  'README.md']

# %%
def api_call(endpoint,parameters):
    call = requests.get(endpoint.format(**parameters), headers=headers)
    response = call.json()
    
    return response

# %%
for access_type in legacy_pagecount_access_types:
    api_params = json.loads(legacy_pagecount.format(placeholder=access_type))
    monthly_pagecount = api_call(pagecount_endpoint, api_params)['items']
    with open('raw/pagecounts_{}_20080101-20160801.json'.format(access_type), 'w') as json_file:
        json.dump(monthly_pagecount, json_file)
    

for access_type in pageview_access_types:
    api_params = json.loads(pageview.format(placeholder=access_type))
    monthly_pageview = api_call(pageview_endpoint, api_params)['items']
    with open('raw/pageviews_{}_200150701-20210901.json'.format(access_type), 'w') as json_file:
        json.dump(monthly_pagecount, json_file)

# %%
monthly_pagecount
# Out:
# [{'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2014100100',
#   'count': 3091546685},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2014110100',
#   'count': 3027489668},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2014120100',
#   'count': 3278950021},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2015010100',
#   'count': 3485302091},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2015020100',
#   'count': 3091534479},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2015030100',
#   'count': 3330832588},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2015040100',
#   'count': 3222089917},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2015050100',
#   'count': 3334069483},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2015060100',
#   'count': 3038162463},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2015070100',
#   'count': 3254472695},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2015080100',
#   'count': 3268487582},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2015090100',
#   'count': 3172429827},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2015100100',
#   'count': 3246082505},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2015110100',
#   'count': 3218234512},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2015120100',
#   'count': 3387411863},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2016010100',
#   'count': 3739628742},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2016020100',
#   'count': 3333231392},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2016030100',
#   'count': 3419853636},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2016040100',
#   'count': 3301385124},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2016050100',
#   'count': 3418435805},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2016060100',
#   'count': 3372618063},
#  {'project': 'en.wikipedia',
#   'access-site': 'mobile-site',
#   'granularity': 'monthly',
#   'timestamp': '2016070100',
#   'count': 3500661121}]

# %%
monthly_pageview
# Out:
# [{'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2015070100',
#   'views': 109624146},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2015080100',
#   'views': 109669149},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2015090100',
#   'views': 96221684},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2015100100',
#   'views': 94523777},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2015110100',
#   'views': 94353925},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2015120100',
#   'views': 99438956},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2016010100',
#   'views': 106432767},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2016020100',
#   'views': 92414130},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2016030100',
#   'views': 97899074},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2016040100',
#   'views': 81719003},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2016050100',
#   'views': 98738513},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2016060100',
#   'views': 96908466},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2016070100',
#   'views': 101398640},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2016080100',
#   'views': 97172509},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2016090100',
#   'views': 83037939},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2016100100',
#   'views': 67174886},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2016110100',
#   'views': 83623769},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2016120100',
#   'views': 128976033},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2017010100',
#   'views': 211813191},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2017020100',
#   'views': 189059134},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2017030100',
#   'views': 184098693},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2017040100',
#   'views': 115051969},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2017050100',
#   'views': 118805669},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2017060100',
#   'views': 115285847},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2017070100',
#   'views': 124118219},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2017080100',
#   'views': 119171796},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2017090100',
#   'views': 114615188},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2017100100',
#   'views': 115580485},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2017110100',
#   'views': 112953288},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2017120100',
#   'views': 121007315},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2018010100',
#   'views': 129767843},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2018020100',
#   'views': 112583110},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2018030100',
#   'views': 121792838},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2018040100',
#   'views': 119494176},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2018050100',
#   'views': 127894954},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2018060100',
#   'views': 124837607},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2018070100',
#   'views': 134236905},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2018080100',
#   'views': 131441105},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2018090100',
#   'views': 123299034},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2018100100',
#   'views': 125394463},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2018110100',
#   'views': 123741294},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2018120100',
#   'views': 134493010},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2019010100',
#   'views': 141789448},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2019020100',
#   'views': 123578688},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2019030100',
#   'views': 134970454},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2019040100',
#   'views': 128101103},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2019050100',
#   'views': 135060026},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2019060100',
#   'views': 132861082},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2019070100',
#   'views': 141040639},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2019080100',
#   'views': 141066972},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2019090100',
#   'views': 133918888},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2019100100',
#   'views': 137392229},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2019110100',
#   'views': 138019922},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2019120100',
#   'views': 148918364},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2020010100',
#   'views': 159975996},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2020020100',
#   'views': 143596541},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2020030100',
#   'views': 148989800},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2020040100',
#   'views': 172919648},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2020050100',
#   'views': 142644741},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2020060100',
#   'views': 21933093},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2020070100',
#   'views': 134547886},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2020080100',
#   'views': 155433481},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2020090100',
#   'views': 147202116},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2020100100',
#   'views': 161368361},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2020110100',
#   'views': 163773950},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2020120100',
#   'views': 169615667},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2021010100',
#   'views': 179803366},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2021020100',
#   'views': 156834531},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2021030100',
#   'views': 165038839},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2021040100',
#   'views': 162260497},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2021050100',
#   'views': 166485079},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2021060100',
#   'views': 150704624},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2021070100',
#   'views': 161461155},
#  {'project': 'en.wikipedia',
#   'access': 'mobile-app',
#   'agent': 'user',
#   'granularity': 'monthly',
#   'timestamp': '2021080100',
#   'views': 161381193}]

# %%
legacy_pagecount.format(placeholder= 'hello')
# Out:
# '{"project" : "en.wikipedia.org",\n                 "access-site" : "hello",\n                 "granularity" : "monthly",\n                 "start" : "2008010100",\n                 "end" : "2016080100"\n                    }'

# %%
legacy_pagecount
# Out:
# '{"project" : "en.wikipedia.org",\n                 "access-site" : "{placeholder}",\n                 "granularity" : "monthly",\n                 "start" : "2008010100",\n                 "end" : "2016080100"\n                    }'
